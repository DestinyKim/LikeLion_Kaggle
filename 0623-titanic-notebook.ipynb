# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

# %%
train = pd.read_csv('/kaggle/input/titanic/train.csv')
test = pd.read_csv('/kaggle/input/titanic/test.csv')

train.shape, test.shape

# %%
train.head()

# %%
train.columns

# %%
# 만약 전체 열이 확인 안 될 때,
for col in train.columns:
    print("column : ", col)
    print(train[col].head()) 
    print()

# %%
train.info()

# %%
train.describe()

# %%
# 결측치 확인
train.isnull().sum()

# %%
plt.figure(figsize=(10,7))
sns.heatmap(train.isnull(), yticklabels=False, cbar=False, cmap='GnBu')

# %%
sns.heatmap(train.isnull(), yticklabels=True, cbar=False, cmap='GnBu')

# %%
sns.heatmap(train.isnull(), yticklabels=False, cbar=True, cmap='GnBu')

# %%
sns.heatmap(train.isnull(), yticklabels=False, cbar=True, cmap='Accent')

# %%
sns.heatmap(train.isnull(), yticklabels=False, cbar=True, cmap='rocket_r')

# %%
num_cols = [col for col in train.columns[:12] if train[col].dtype in ['int64', 'float64'] ]
print(num_cols)
train[num_cols].describe()

# %%
cat_cols = [col for col in train.columns[:12] if train[col].dtype in ['O'] ]
train[cat_cols].describe()

# %%
train.columns, test.columns

# %% [markdown]
# ### 생존자가 몇 명일까?

# %%
sns.countplot(x="Survived", data = train)

# %%
* 생존자가 약 350명, 사망자가 약 550명 정도 되는 것 같다.
* 생존자가 적은 편이다.

# %% [markdown]
# ### PClass별 생존자는 얼마나 되나?
#     * PClass, 생존자(Survived)

# %%
sns.countplot(x="Pclass", hue="Survived", data=train)

# %%
#* 1등급은 생존자가 많다.
#* 3등급에서의 사망자가 많다.

# [가설1] 혹시 1등급은 여성이 많아서 그런 것은 아닐까? (남성이 더 많다. 이 가설은 생각을 해보자.)
# [추가가설] 남성이 구조에 후 순위에 있었다. 3등급은 남성이 많기 때문에 ... ( 어느 정도 맞는 것 같다.)
sns.countplot(x='Pclass', hue='Sex', data=train)

# %%
# [가설2] Pclass별 나이를 확인해 봐야 하는데...
#   -- 나이가 많은 분들이 많이 구조된 것 같다.
#   -- 나이가 적은 사람들은 1등급에 별로 없다.
# 생존에 영향을 끼치는 요소 - Age, Pclass
sns.histplot(x='Age',hue='Pclass', data=train)

# %%
# [추가가설] 남성이 구조에 후 순위에 있었다. 3등급은 남성이 많기 때문에 ... ( 어느 정도 맞는 것 같다.)
# 3등급
# 남성, 여성
train_m = train[train['Sex']=='male']   #데이터에서 남자만 가져오기
train_f = train[train['Sex']=='female']   #데이터에서 여자만 가져오기

plt.figure(figsize=(14,10))
plt.subplot(1,2,1)
sns.histplot(x='Age',hue='Pclass', data=train_m)
plt.subplot(1,2,2)
sns.histplot(x='Age',hue='Pclass', data=train_f)

# %%
# 생존에 영향을 끼치는 요소 - Age, Pclass, Sex
train.columns

# %%
train.corr()

# %%
### 5-7 Embarked가 어떤 영향을 끼쳤는지?
### Southampton에서 탑승한 사람들이 상대적으로 사망자가 많다.
### 영향을 어느정도 끼치는 것 같다.
sns.countplot(x="Embarked", hue="Survived", data=train)

# %%
### 5-8 Fare가 히스토그램을 찍어보고 분포를 확인해 보기. Fare가 생존에 영향을 끼칠까요?
### Fare도 생존에 어느정도 영향을 끼친다.
plt.figure(figsize=(15,10))
sns.histplot(x='Fare', hue="Survived", data=train)
